# %%
import pandas as pd
import pandas as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df_white_wine = pd.read_csv("winequality-white.csv", sep = ";")
df_white_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
df_white_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
df_white_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %% [markdown]
# ### No missing data point and have 4898 samples in the data set

# %%
df_white_wine.index
# Out:
# RangeIndex(start=0, stop=4898, step=1)

# %%
# r = sns.PairGrid(df_white_wine, hue = "quality")# phan lớp theo quality, quality có từ 3-9, có 6 màu
# r.map(plt.scatter)

# %% [markdown]
# ### Using a suitable graph to visualize each feature of the data set

# %%
sns.histplot( x = "volatile acidity", data=df_white_wine, binwidth = 0.05, color="#1cc414", edgecolor="#4fa83b", kde=True)

plt.title("My 12th graph")
# Out:
# Text(0.5, 1.0, 'My 12th graph')

# %%
sns.set(style="whitegrid")
ax = sns.scatterplot(y = "pH", x = df_white_wine.index  , data=df, size = 2)
ax.set(xlabel = 'Number of sampling times', ylabel = 'pH')
plt.title('My first graph')
plt.show()

# %%
sns.set(style="whitegrid")
ax = sns.scatterplot(y = "citric acid", x = df_white_wine.index  , data=df, size = 2)
ax.set(xlabel = 'Number of sampling times', ylabel = 'Citric acid')
plt.title('The second graph')
plt.show()

# %%
sns.set(style="whitegrid")
ax = sns.scatterplot(y = "residual sugar", x = df_white_wine.index  , data=df, size = 2)
ax.set(xlabel = 'Number of sampling times', ylabel = 'residual sugar')
plt.title('The third graph')
plt.show()

# %%
sns.set(style="whitegrid")
ax = sns.scatterplot(y = "chlorides", x = df_white_wine.index  , data=df, size = 2)
ax.set(xlabel = 'Number of sampling times', ylabel = 'Chlorides')
plt.title('The 4th graph')
plt.show()

# %%
sns.set(style="whitegrid")
ax = sns.scatterplot(y = "free sulfur dioxide", x = df_white_wine.index  , data=df, size = 2)
ax.set(xlabel = 'Number of sampling times', ylabel = 'Free sulfur dioxide')
plt.title('The 5th graph')
plt.show()

# %%
sns.set(style="whitegrid")
ax = sns.scatterplot(y = "total sulfur dioxide", x = df_white_wine.index  , data=df, size = 2)
ax.set(xlabel = 'Number of sampling times', ylabel = 'Total sulfur dioxide')
plt.title('The 6th graph')
plt.show()

# %%
sns.set(style="whitegrid")
ax = sns.scatterplot(y = "density", x = df_white_wine.index  , data=df, size = 2)
ax.set(xlabel = 'Number of sampling times', ylabel = 'Density')
plt.title('The 7th graph')
plt.show()

# %%
sns.set(style="whitegrid")
ax = sns.scatterplot(y = "sulphates", x = df_white_wine.index  , data=df, size = 2)
ax.set(xlabel = 'Number of sampling times', ylabel = 'Sulphates')
plt.title('The 8th graph')
plt.show()

# %%
sns.set(style="whitegrid")
ax = sns.scatterplot(y = "alcohol", x = df_white_wine.index  , data=df, size = 2)
ax.set(xlabel = 'Number of sampling times', ylabel = 'Alcohol')
plt.title('The 9th graph')
plt.show()

# %%
sns.histplot( x = "quality", data=df_white_wine, binwidth = 0.5 )
plt.title('The 10th graph')
plt.show()

# %%
sns.catplot(x = "pH", data=df_white_wine, aspect=10, kind="count" )
plt.title("My 12th graph")
plt.show()
# thống kê số lần xuất hiện

# %% [markdown]
# ### The range of each feature of the dataset

# %%
for i in range(0,12):
    
    Min = df_white_wine.iloc[:,i:i+1].min().values
    Max = df_white_wine.iloc[:, i:i+1].max().values
    minus = Max - Min
    print("The range of {}".format(df_white_wine.columns[i]) + " of the dataset %.2f" % minus)
# Out:
# The range of fixed acidity of the dataset 10.40
# The range of volatile acidity of the dataset 1.02
# The range of citric acid of the dataset 1.66
# The range of residual sugar of the dataset 65.20
# The range of chlorides of the dataset 0.34
# The range of free sulfur dioxide of the dataset 287.00
# The range of total sulfur dioxide of the dataset 431.00
# The range of density of the dataset 0.05
# The range of pH of the dataset 1.10
# The range of sulphates of the dataset 0.86
# The range of alcohol of the dataset 6.20
# The range of quality of the dataset 6.00
