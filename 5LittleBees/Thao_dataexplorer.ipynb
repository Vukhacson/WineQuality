# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
red_wine = pd.read_csv('/Users/hoangminhthao/Documents/GitHub/WineQuality/Data set/winequality-red.csv', sep=';')
#red_wine = red_wine['fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"'].str.split('\;',expand=True)
#red_wine.columns = ['fixed acidity',"volatile acidity","citric acid","residual sugar","chlorides","free sulfur dioxide","total sulfur dioxide","density","pH","sulphates","alcohol","quality"]
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
#Read class in each column

len(red_wine['fixed acidity'].value_counts())
len(red_wine['volatile acidity'].value_counts())
len(red_wine['citric acid'].value_counts())
len(red_wine['residual sugar'].value_counts())
len(red_wine['chlorides'].value_counts())
len(red_wine['free sulfur dioxide'].value_counts())
len(red_wine['total sulfur dioxide'].value_counts())
len(red_wine['density'].value_counts())
len(red_wine['pH'].value_counts())
len(red_wine['sulphates'].value_counts())
len(red_wine['alcohol'].value_counts())
len(red_wine['quality'].value_counts())
# Out:
# 6

# %%
#Correlation
corr_red = red_wine.corr()
sns.heatmap(corr_red)
# Out:
# <AxesSubplot:>

# %%
#Covariance
cov_red = red_wine.cov()
sns.heatmap(cov_red)
# Out:
# <AxesSubplot:>

# %%
#Info and type
red_wine['fixed acidity'].info()
red_wine['volatile acidity'].info()
red_wine['citric acid'].info()
red_wine['residual sugar'].info()
red_wine['chlorides'].info()
red_wine['free sulfur dioxide'].info()
red_wine['total sulfur dioxide'].info()
red_wine['density'].info()
red_wine['pH'].info()
red_wine['sulphates'].info()
red_wine['alcohol'].info()
red_wine['quality'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1599 entries, 0 to 1598
# Series name: fixed acidity
# Non-Null Count  Dtype
# --------------  -----
# 1599 non-null   float64
# dtypes: float64(1)
# memory usage: 12.6 KB
# <class 'pandas.core.series.Series'>
# RangeIndex: 1599 entries, 0 to 1598
# Series name: volatile acidity
# Non-Null Count  Dtype
# --------------  -----
# 1599 non-null   float64
# dtypes: float64(1)
# memory usage: 12.6 KB
# <class 'pandas.core.series.Series'>
# RangeIndex: 1599 entries, 0 to 1598
# Series name: citric acid
# Non-Null Count  Dtype
# --------------  -----
# 1599 non-null   float64
# dtypes: float64(1)
# memory usage: 12.6 KB
# <class 'pandas.core.series.Series'>
# RangeIndex: 1599 entries, 0 to 1598
# Series name: residual sugar
# Non-Null Count  Dtype
# --------------  -----
# 1599 non-null   float64
# dtypes: float64(1)
# memory usage: 12.6 KB
# <class 'pandas.core.series.Series'>
# RangeIndex: 1599 entries, 0 to 1598
# Series name: chlorides
# ...

# %%
#Visualize(grid map 2x6)

fix_acid = red_wine['fixed acidity']
vol_acid = red_wine['volatile acidity']
cit_acid = red_wine['citric acid']
res_sur = red_wine['residual sugar']
clo = red_wine['chlorides']
fsd = red_wine['free sulfur dioxide']
tsd = red_wine['total sulfur dioxide']
dens = red_wine['density']
pH = red_wine['pH']
sul = red_wine['sulphates']
alc = red_wine['alcohol']
qual = red_wine['quality']

fig, axs = plt.subplots(6, 2, figsize=(20, 12), constrained_layout = True)
axs[0, 0].hist(fix_acid, bins=200)
axs[0, 0].set_title("Fixed acidity")
axs[0, 1].hist(vol_acid, bins=200)
axs[0, 1].set_title("Volatile acidity")
axs[1, 0].hist(cit_acid, bins=200)
axs[1, 0].set_title("Citric acid")
axs[1, 1].hist(res_sur, bins=200)
axs[1, 1].set_title("Residual sugar")
axs[2, 0].hist(clo, bins=200)
axs[2, 0].set_title("Chlorides")
axs[2, 1].hist(fsd, bins=200)
axs[2, 1].set_title('Free sulfur dioxide')
axs[3, 0].hist(tsd, bins=200)
axs[3, 0].set_title('Total sulfur dioxide')
axs[3, 1].hist(dens, bins=200)
axs[3, 1].set_title('Density')                    
axs[4, 0].hist(pH, bins=200)
axs[4, 0].set_title("pH")                   
axs[4, 1].hist(sul, bins=200)
axs[4, 1].set_title('Sulphates')                    
axs[5, 0].hist(alc, bins=200)
axs[5, 0].set_title('Alcohol')                    
axs[5, 1].hist(qual, bins=200)
axs[5, 1].set_title("Quality")
# Out:
# Text(0.5, 1.0, 'Quality')

# %%
#66 scatter

red_wine.plot(kind='scatter', x='fixed acidity', y='volatile acidity', figsize=(6,6))
red_wine.plot(kind='scatter', x='fixed acidity', y='citric acid', figsize=(6,6))
red_wine.plot(kind='scatter', x='fixed acidity', y='residual sugar', figsize=(6,6))
red_wine.plot(kind='scatter', x='fixed acidity', y='chlorides', figsize=(6,6))
red_wine.plot(kind='scatter', x='fixed acidity', y='free sulfur dioxide', figsize=(6,6))
red_wine.plot(kind='scatter', x='fixed acidity', y='total sulfur dioxide', figsize=(6,6))
red_wine.plot(kind='scatter', x='fixed acidity', y='density', figsize=(6,6))
red_wine.plot(kind='scatter', x='fixed acidity', y='pH', figsize=(6,6))
red_wine.plot(kind='scatter', x='fixed acidity', y='sulphates', figsize=(6,6))
red_wine.plot(kind='scatter', x='fixed acidity', y='alcohol', figsize=(6,6))
red_wine.plot(kind='scatter', x='fixed acidity', y='quality', figsize=(6,6))

red_wine.plot(kind='scatter', x='volatile acidity', y='citric acid', figsize=(6,6))
red_wine.plot(kind='scatter', x='volatile acidity', y='residual sugar', figsize=(6,6))
red_wine.plot(kind='scatter', x='volatile acidity', y='chlorides', figsize=(6,6))
red_wine.plot(kind='scatter', x='volatile acidity', y='free sulfur dioxide', figsize=(6,6))
red_wine.plot(kind='scatter', x='volatile acidity', y='total sulfur dioxide', figsize=(6,6))
red_wine.plot(kind='scatter', x='volatile acidity', y='density', figsize=(6,6))
red_wine.plot(kind='scatter', x='volatile acidity', y='pH', figsize=(6,6))
red_wine.plot(kind='scatter', x='volatile acidity', y='sulphates', figsize=(6,6))
red_wine.plot(kind='scatter', x='volatile acidity', y='alcohol', figsize=(6,6))
red_wine.plot(kind='scatter', x='volatile acidity', y='quality', figsize=(6,6))

red_wine.plot(kind='scatter', x='citric acid', y='residual sugar', figsize=(6,6))
red_wine.plot(kind='scatter', x='citric acid', y='chlorides', figsize=(6,6))
red_wine.plot(kind='scatter', x='citric acid', y='free sulfur dioxide', figsize=(6,6))
red_wine.plot(kind='scatter', x='citric acid', y='total sulfur dioxide', figsize=(6,6))
red_wine.plot(kind='scatter', x='citric acid', y='density', figsize=(6,6))
red_wine.plot(kind='scatter', x='citric acid', y='pH', figsize=(6,6))
red_wine.plot(kind='scatter', x='citric acid', y='sulphates', figsize=(6,6))
red_wine.plot(kind='scatter', x='citric acid', y='alcohol', figsize=(6,6))
red_wine.plot(kind='scatter', x='citric acid', y='quality', figsize=(6,6))
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='quality'>

# %%
red_wine.plot(kind='scatter', x='residual sugar', y='chlorides', figsize=(6,6))
red_wine.plot(kind='scatter', x='residual sugar', y='free sulfur dioxide', figsize=(6,6))
red_wine.plot(kind='scatter', x='residual sugar', y='total sulfur dioxide', figsize=(6,6))
red_wine.plot(kind='scatter', x='residual sugar', y='density', figsize=(6,6))
red_wine.plot(kind='scatter', x='residual sugar', y='pH', figsize=(6,6))
red_wine.plot(kind='scatter', x='residual sugar', y='sulphates', figsize=(6,6))
red_wine.plot(kind='scatter', x='residual sugar', y='alcohol', figsize=(6,6))
red_wine.plot(kind='scatter', x='residual sugar', y='quality', figsize=(6,6))

red_wine.plot(kind='scatter', x='chlorides', y='free sulfur dioxide', figsize=(6,6))
red_wine.plot(kind='scatter', x='chlorides', y='total sulfur dioxide', figsize=(6,6))
red_wine.plot(kind='scatter', x='chlorides', y='density', figsize=(6,6))
red_wine.plot(kind='scatter', x='chlorides', y='pH', figsize=(6,6))
red_wine.plot(kind='scatter', x='chlorides', y='sulphates', figsize=(6,6))
red_wine.plot(kind='scatter', x='chlorides', y='alcohol', figsize=(6,6))
red_wine.plot(kind='scatter', x='chlorides', y='quality', figsize=(6,6))

red_wine.plot(kind='scatter', x='free sulfur dioxide', y='total sulfur dioxide', figsize=(6,6))
red_wine.plot(kind='scatter', x='free sulfur dioxide', y='density', figsize=(6,6))
red_wine.plot(kind='scatter', x='free sulfur dioxide', y='pH', figsize=(6,6))
red_wine.plot(kind='scatter', x='free sulfur dioxide', y='sulphates', figsize=(6,6))
red_wine.plot(kind='scatter', x='free sulfur dioxide', y='alcohol', figsize=(6,6))
red_wine.plot(kind='scatter', x='free sulfur dioxide', y='quality', figsize=(6,6))

red_wine.plot(kind='scatter', x='total sulfur dioxide', y='density', figsize=(6,6))
red_wine.plot(kind='scatter', x='total sulfur dioxide', y='pH', figsize=(6,6))
red_wine.plot(kind='scatter', x='total sulfur dioxide', y='sulphates', figsize=(6,6))
red_wine.plot(kind='scatter', x='total sulfur dioxide', y='alcohol', figsize=(6,6))
red_wine.plot(kind='scatter', x='total sulfur dioxide', y='quality', figsize=(6,6))

red_wine.plot(kind='scatter', x='density', y='pH', figsize=(6,6))
red_wine.plot(kind='scatter', x='density', y='sulphates', figsize=(6,6))
red_wine.plot(kind='scatter', x='density', y='alcohol', figsize=(6,6))
red_wine.plot(kind='scatter', x='density', y='quality', figsize=(6,6))

red_wine.plot(kind='scatter', x='pH', y='sulphates', figsize=(6,6))
red_wine.plot(kind='scatter', x='pH', y='alcohol', figsize=(6,6))
red_wine.plot(kind='scatter', x='pH', y='quality', figsize=(6,6))
  
red_wine.plot(kind='scatter', x='sulphates', y='alcohol', figsize=(6,6))
red_wine.plot(kind='scatter', x='sulphates', y='quality', figsize=(6,6))

red_wine.plot(kind='scatter', x='alcohol', y='quality', figsize=(6,6))
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='quality'>
