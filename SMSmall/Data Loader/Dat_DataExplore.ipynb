# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
'''
    Using a suitable graph to visualize each feature of the data set
'''
# Out:
# '\n    Using a suitable graph to visualize each feature of the data set\n'

# %%
df_white_wine = pd.read_csv("G:\Learning resource\Github\WineQuality\Data set\winequality-white.csv", sep=';')
df_white_wine

# %%
df_red_wine = pd.read_csv("G:\Learning resource\Github\WineQuality\Data set\winequality-red.csv", sep=';')
df_red_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
red_wine_feature = df_red_wine.columns.values
red_feature_reshaped = red_wine_feature.reshape(6,2)


red_feature = [0 for i in range(12)]

for i in range(12):
    red_feature[i] = df_red_wine.iloc[:,i].squeeze()
    
red_wine_feature
# red_feature_reshaped
# Out:
# array(['fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'], dtype=object)

# %%
fig, axs = plt.subplots(6, 2, figsize = (15,45))

cmap = plt.get_cmap('viridis')
colors = cmap(np.linspace(4, 5, len(red_wine_feature)))

for i in range(6):
    for j in range(2):
        feature = red_feature_reshaped[i,j]
        axs[i,j].hist(df_red_wine[feature].values, bins=30)
        axs[i,j].set(title=feature, ylabel='Count')

# %%
count_feature = red_feature[-1].value_counts()
print(count_feature)

plt.pie(count_feature, startangle=90, labels=count_feature.index)
plt.title("{}".format(count_feature.name))
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64
# Text(0.5, 1.0, 'quality')
